# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from scipy.stats import pearsonr, levene

# %%
data = pd.read_csv('C:/Users/tadeu/Documents/Projetos/Cleverly/data/Amazon_Reviews_Clothing_Shoes_and_Jewelry_5_sample.csv')
data.dropna(inplace=True)
data.reset_index(drop=True, inplace=True)

# %%
#Data Overview

data.dtypes
# Out:
# asin              object
# helpful           object
# overall            int64
# reviewText        object
# reviewTime        object
# reviewerID        object
# reviewerName      object
# summary           object
# unixReviewTime     int64
# dtype: object

# %%
#need to retrieve the values of helpfulness separetly
yes =[]
total=[]

for a in range(0,len(data)):
    over = data.helpful[a].strip('[]')
    yes.append(over.split(',')[0])
    total.append(over.split(',')[1])

data.insert(1, 'yes', pd.to_numeric(yes))
data.insert(2, 'total', pd.to_numeric(total))
data.drop('helpful',1)
# Out:
#              asin  yes  total  overall  \
# 0      B00008ID1O    3      4        5
# 1      B00008ID1O    1      1        4
# 2      B00008ID1O    7      7        1
# 3      B00008ID1O    0      2        3
# 4      B00008ID1O    3      3        5
# 5      B00008ID1O    2      2        4
# 6      B00008ID1O    2      2        5
# 7      B00008ID1O    0      0        5
# 8      B00008ID1O    0      0        5
# 9      B00008ID1O    7      7        1
# 10     B00008ID1O    3      3        4
# 11     B00008KH9C    3      3        5
# 12     B00008KH9C    1      1        5
# 13     B00008KH9C    0      0        5
# 14     B00008KH9C    0      0        5
# 15     B00008KH9C    0      0        3
# 16     B00008KH9C    0      0        5
# 17     B00008KH9C    4      4        5
# 18     B00008KH9C    2      3        3
# 19     B00008KH9C    6      6        5
# 20     B00008KH9C    2      2        5
# 21     B00008KH9C    5      5        5
# 22     B00008KH9C    0      0        5
# 23     B00008KH9C    4      4        4
# 24     B00008KH9C    0      1        3
# 25     B00008KH9C   25     32        5
# 26     B00008KH9C    0      0        2
# 27     B00008KH9C    6      6        5
# 28     B00008KH9C    0      0        5
# 29     B00008KH9C    2      2        5
# ...           ...  ...    ...      ...
# 14269  B00ISRCJYM    0      0        5
# 14270  B00ISRCJYM    0      0        4
# 14271  B00ISRCJYM    1      1        5
# 14272  B00ISRCJYM    0      0        5
# 14273  B00ISRCJYM    0      0        5
# 14274  B00IWCCW2W    4      5        5
# 14275  B00IWCCW2W    1      2        5
# 14276  B00IWCCW2W    1      2        5
# 14277  B00IWCCW2W    0      0        5
# 14278  B00IWCCW2W    1      1        1
# 14279  B00IWCCW2W    0      0        4
# 14280  B00IWCCW2W    1      3        3
# 14281  B00IWCCW2W    3      4        5
# 14282  B00IWCCW2W    0      0        1
# 14283  B00IWCCW2W    0      0        5
# 14284  B00J6OOYI0    0      0        5
# 14285  B00J6OOYI0    0      0        5
# 14286  B00J6OOYI0    1      1        5
# 14287  B00J6OOYI0    0      0        5
# 14288  B00J6OOYI0    0      0        5
# 14289  B00KA2X4QK    0      0        3
# 14290  B00KA2X4QK    0      0        5
# 14291  B00KA2X4QK    0      0        5
# 14292  B00KA2X4QK    0      0        5
# 14293  B00KA2X4QK    0      0        5
# 14294  B00KGCLROK    1      1        2
# 14295  B00KGCLROK    0      0        5
# 14296  B00KGCLROK    0      0        5
# 14297  B00KGCLROK    1      1        5
# 14298  B00KGCLROK    0      0        5
#
#                                               reviewText   reviewTime  \
# 14290  Great design has a quality and efficient look....  07 20, 2014
# 14291  I expected an attractive backpack from Kenneth...  06 29, 2014
# 14292  This is a heavy duty back pack, with padded po...  06 30, 2014
# 14293  This pack looks really stylish, I got several ...  06 30, 2014
# 14294  These were a free sample for review.  I was ex...  06 21, 2014
# 14295  My stepmother does yoga in bare feet or regula...   07 3, 2014
# 14296  These socks are very nicely made and quite com...  06 22, 2014
# 14297  You don&#8217;t have to be a yoga or martial a...   07 5, 2014
# 14298  These are cozy and complements well for yoga. ...  06 24, 2014
#
#            reviewerID                                reviewerName  \
# 0       ARZLW6MFV58E9                  Denise Elkin-andrews "dee"
# 1       A454H175JAT32                                       Emily
# 2      A1X5NM3HXQANFL                              Jasminenirvana
# 3       AVKF05BAX2Z3I                                K. H. Noland
# 4       AQJWVL7YBSMOL                                Mail Debaser
# 5      A3DF2RIXV8DRJN                                 M. Hofelich
# 6      A1W64ZEL2TQBPD                               Naney "Naney"
# 7      A27J2K9RU1JCFE               onlineonlyJAG "OnlineonlyJAG"
# 8      A1RF0CB0FH2LD8                                       Sivan
# 9       APF6PI31359U5                                        Snow
# 10     A26E6RLP91XOEN                                       Susan
# 11     A17ED9J0J0UJ9G                         A. Gehlke "Cat Mom"
# 12     A1POKQ821ZBYQ8                            Alexis Humphries
# 13     A265EJE2WINJY0                                      Amanda
# 14     A3V4DUBZJBKEZ3                     Bargain Shopper "Me Me"
# 15     A1OGM86F9XF5M3                     blueazulli "blueazulli"
# 16     A1NVER4FI1K13K                                   bollycats
# 17     A3P8WZ8E14G8SZ                              Bunkster Brown
# 18     A3Q1H0YQZYA478                                Cari Johnson
# 19     A2ZY49IDE6TY5I             Crabigail Cassidy "Crabby Abby"
# 20     A2L4BFVLQBY80D                         Darci Noelle Maurer
# 21     A3PHWH3X4AW5WZ            Deborah A. Damiano "Avid reader"
# 22     A3LEOT4WYQ45D2                                       Diane
# 23     A3QG68ROZVEYN0                                         ELS
# 24     A1Q718T80K520W                             Fsanyc "Fsanyc"
# 25     A1OK6GRKNHISTG                       Gypsy Tejas "Gypsy T"
# 26     A235XRSVIHKUNW                                       Holly
# 27     A21IMS76KY1VPC                        honeysmother "Robin"
# 28       AVV2V46YR89K                                        Jazz
# 29      A2IX78SEP2XHA                                        Jess
# ...               ...                                         ...
# 14269  A3GDU7EDP0P88F     Amazon Customer "creature of the earth"
# 14270   AEWX9NVOK8N61                                     ginbfun
# 14271   AD6IW4HGRY4M9                                Paris Tx Guy
# 14272  A1KKDRMZ2C5C5I                 S. K. Lovett "Just Lookin'"
# 14273  A3RGPR30UD33ZV                        S. Martin "Chefanie"
# 14274   A7VL77G6QFKGU                             Amazon Customer
# 14275   A9WC1LJIL83JP                                        Angi
# 14276  A1E9ILRMBVSI9G                                 cathi davis
# 14277  A2UKYGJRLV64II                                    Gorgeous
# 14278  A2ZGGZV7SJ8TP2                                        KAJA
# 14279  A1XQ5EHXRL1XUU                                      Kristy
# 14280  A2SB3ZJMNHSV57                              Manuel Sanchez
# 14281  A1WQ69ZC4B1PN6                                     nitabk1
# 14282  A12AD65QAZGCEQ                                      Rosemm
# 14291                          Heavy Duty, High Capacity      1404000000
# 14292                                   Laptop back pack      1404086400
# 14293                             well made and stylish!      1404086400
# 14294                               Wanted to love these      1403308800
# 14295   My stepmother was impressed with the extra grip.      1404345600
# 14296     A bit fussy to get on, but they work very well      1403395200
# 14297  Very nice, comfortable non-slip socks for yoga...      1404518400
# 14298                                              Cozy!      1403568000
#
# [14299 rows x 10 columns]

# %% [markdown]
# ### Is there a correlation between the rating of the product and the helpfulness of the review?

# %%
plt.scatter(data['yes'], data['overall'])

print(levene(data['yes'], data['total']))

corr, _ = pearsonr(data['yes'], data['overall'])
print('Pearsons correlation: %.3f' % corr)

#There is no correlation between he rating of the product and the helpfulness of the review
# Out:
# LeveneResult(statistic=7.462852580981266, pvalue=0.006302376235862596)
# Pearsons correlation: -0.011

# %% [markdown]
# ### Lets look now understand our reviewers

# %%
reviewers = data['yes'].groupby(data['reviewerID']).count()
print(data.groupby('reviewerID')['yes'].sum().sort_values(ascending=False))
      
#print("Top 20 Reviewers \n"))

sorted_reviewers = reviewers.sort_values(ascending=False)
print("Top 20 Reviewers \n")
print(sorted_reviewers[:20], end='\n\n')
print('Most Reviewed Reviewer, A2GA55P7WGHJCP - has {} helpful reviews.'.format(reviewers.max()))
# Out:
# reviewerID
# A1IU7S4HCK1XK0           408
# A30NHVVC62LJMK           267
# A2R6RA8FRBS608           152
# AFHYEO3Y1IIDD            107
# A2NZIF62RSX9VW           105
# A1M54RKARXK8DU            98
# A2I4JU06JM47LR            96
# A3PAPZE14TIHP8            85
# A1RXXWA0HPGSU             81
# A1JXY9I578VQ3O            75
# A18X6ZT4AEYVKB            75
# AMYI4FBXF68X4             69
# AEVTLUYR5JC8H             68
# ACL6H8Q17XQPN             66
# A2N3UF4KPCZFXB            66
# A24JGUKZEYVQJW            62
# A37ZCYY3CGEJFX            56
# A325Q8LI2V97XV            53
# A3SVNQ9HDLDPVH            53
# A335713MZIGYB1            53
# AXQW6IS0Z62BR             52
# A3R1WL67CFHL0Z            52
# A2KB402X85NQML            51
# A10QZ2QP9EMW71            50
# A3FBOUQQWKO2T2            49
# A1DU4P2QWGA2VF            49
# A3MJRWQQECRA7             48
# A1IGCUY11IG8I2            48
# A2CKWT89SZKCA3            47
# A1WOMXOEX90ARI            47
#                         ...
# A39YQPI318NNYY             0
# A39YI13KZY0TTH             0
# A39X53LTAIP1R4             0
# A39WQJ1LLOFFHB             0
# A39VJG4HMY69EV             0
# A39UWVEBBJFZCQ             0
# A39TOXC7IRVEGG             0
# A39R4XXSV5I3PO             0
# A39R21DJN227VL             0
# A39PX31IKGXZP7             0
# A3A52DETIFZNZS             0
# A3A6OAAUVUMSTH             0
# A3AFEI5J4VZIHX             0
# A3A79B8FRJ64UV             0
# A3AF1CIET0NFPN             0
# A3AEE5J8TOWGBD             0
# A3ADU4J047UKT1             0
# A3ADPEYMKZ17TT             0
# A3ACL6CSLF4LSX             0
# A3ABHXZARMHREX             0
# A3ABHCX5U08DFJ             0
# A3AAI5TEL4Q0GX             0
# A3A9ZOA81YLPLT             0
# A3A9QVQXFFOGVA             0
# A3A9LLRVAHU6YU             0
# A3A9I8J593L56S             0
# A3A98LQR0K00ZE             0
# A3A8G3JP9H45GH             0
# A3A7INI4XJQS81             0
# A00146182PNM90WNNAZ5Q      0
# Name: yes, Length: 11882, dtype: int64
# Top 20 Reviewers
#
# reviewerID
# A2GA55P7WGHJCP    8
# A2J4XMWKR8PPD0    6
# A34BZM6S9L7QI4    6
# A9J5SLYXUCWO1     5
# A3U5M273GGGOB4    5
# A260QLS8Z33KCQ    5
# A2USMIT2CSA08     5
# AN81JUYW2SL24     5
# A1A81QZOKSEY5P    5
# A3LY749Q2Q3W7S    5
# A38BYCK64K98TI    4
# A1VTCSCH8FFC76    4
# A2R6RA8FRBS608    4
# A37PLBG2R6LLIL    4
# A27CTW0GPEE0AZ    4
# A27J2K9RU1JCFE    4
# A2HYM6GQJSKQ6L    4
# A1U0SGKIDHQE1I    4
# A2ZY49IDE6TY5I    4
# AKBZD4VMJ1FF4     4
# Name: yes, dtype: int64
#
# Most Reviewed Reviewer, A2GA55P7WGHJCP - has 8 helpful reviews.

# %% [markdown]
# ### Have reviews been getting more or less helpful over time?

# %%
data["reviewTime"] = pd.to_datetime(data["reviewTime"])

data['yes'].groupby(data['reviewTime']).sum().plot()


#We can say Yes! The Reviews are getting more helpful!

# %% [markdown]
# # Modelling

# %%
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
import string
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.linear_model import LogisticRegression

# %%
#Retrieve features by removing not important words

# %%
reviews = data['reviewText']

stops = stopwords.words('english')

def tokenize(text):
    tokenized = word_tokenize(text)
    no_punc = []
    for review in tokenized:
        line = "".join(char for char in review if char not in string.punctuation)
        no_punc.append(line)
    tokens = lemmatize(no_punc)
    return tokens


def lemmatize(tokens):
    lmtzr = WordNetLemmatizer()
    lemma = [lmtzr.lemmatize(t) for t in tokens]
    return lemma

reviews = reviews.apply(lambda x: tokenize(x))

# %% [markdown]
# #### Creating my label. Assume a god review just more than 0 to not have a big  variance in dataset numbers

# %%
data['label'] = [1 if x > 0 else 0 for x in data.yes]

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn import linear_model
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score

# %%
x_train, x_test, y_train, y_test = train_test_split(data.reviewText, data.label, random_state=0)

# %%
print(len(x_train))
print(len(x_test))
# Out:
# 10724
# 3575

# %%
# Create feature as counting how many times a word appear

# %%
vectorizer = CountVectorizer().fit(x_train)
X_train = vectorizer.transform(x_train)

# %% [markdown]
# # Model evaluation

# %%
#Use cross validation to tnderstand homogenity of dataset

# %%
scores = cross_val_score(LogisticRegression(), X_train, y_train, cv=5)
print("Mean cross-validation accuracy: {:.3f}".format(np.mean(scores)))
# Out:
# C:\Users\tadeu\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Mean cross-validation accuracy: 0.696

# %%
logreg = LogisticRegression(C=0.1).fit(X_train, y_train)

X_test = vectorizer.transform(x_test)

log_y_pred = logreg.predict(X_test)

# %%
# 72% of accuracy. Not so good. Lets try a simple and efficient ensemble algorithm. Random Tree

# %%
logreg_score = accuracy_score(y_test, log_y_pred)
print("Accuracy:   {:.3f}".format(logreg_score))
# Out:
# Accuracy:   0.728

# %%
# Import the model we are using
from sklearn.ensemble import RandomForestRegressor
# Instantiate model with 1000 decision trees
rf = RandomForestRegressor(n_estimators = 50, random_state = 42)
# Train the model on training data
rf.fit(X_train, y_train);

# %%
#Take very long time to calculate.

# %% [markdown]
# # More time to analyse the count vectorized. Better understand of features retrieve from language analysis.
